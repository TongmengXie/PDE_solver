# %%
import pandas as pd
# Out:
# /home/tongmeng_xie/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# import os
# os.listdir()

temp = pd.read_csv("final_sample3000_ver0_2.csv")
temp.sex_patent = temp.sex_patent.apply(lambda x: 1 if x == 0 else 2)
temp
# Out:
#       patent_id  patent_count       recid  pname_pname_jarowinkler  \
# 0     US290029A           0.0  25137783.0                 1.000000
# 1     US129776A           0.0  19125884.0                 0.638889
# 2     US265109A           0.0  19319070.0                 0.950000
# 3     US169225A           0.0  39793614.0                 1.000000
# 4     US359565A           0.0  16967309.0                 1.000000
# ...         ...           ...         ...                      ...
# 2234  US307517A           0.0   4165317.0                 0.518519
# 2235  US224282A           0.0  42179003.0                 0.590909
# 2236  US347549A           0.0  30459736.0                 0.472222
# 2237  US192442A           1.0   3142468.0                 0.950000
# 2238  US107010A           1.0  27239912.0                 0.472222
#
#       sname_sname_jarowinkler  county_state_county_state_levenshtein  \
# 0                    1.000000                               0.958333
# ...

# %%
temp.columns
# Out:
# Index(['patent_id', 'patent_count', 'recid', 'pname_pname_jarowinkler',
#        'sname_sname_jarowinkler', 'county_state_county_state_levenshtein',
#        'desc_ori_hisco_text_levenshtein', 'occ_similarity_HISCO',
#        'city/metro_level_l_score', 'mean', 'publicationnumber', 'inventor_no',
#        'publication.date', 'full_address', 'pname', 'sname', 'sex_patent',
#        'occupation', 'industry', 'address', 'street', 'city', 'county_state',
#        'state', 'region', 'foreign', 'pname_census', 'sname_census', 'sursim',
#        'age', 'sex_census', 'occhisco', 'ind95us', 'county_state_census',
#        'metrous', 'us1880a_city', 'state_census', 'patent_year',
#        'age_at_inventing', 'occ_similarity_HISCO_sigmoid'],
#       dtype='object')

# %%
view1 = temp[['patent_id', 'patent_count', 'recid', 'publicationnumber', 'inventor_no',
       'publication.date', 'pname', 'pname_census', 'sname', 'sname_census', 'sex_patent', 'sex_census',
       'street', 'city', 'county_state', 'county_state_census',
       'state', 'state_census', 'region', 'foreign',  'sursim',
       'age',
       'metrous', 'us1880a_city',  'patent_year',
       'age_at_inventing']]
view1['gt'] = False
view1
# Out:
# /tmp/ipykernel_2429/2512866848.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   view1['gt'] = False
#       patent_id  patent_count       recid publicationnumber  inventor_no  \
# 0     US290029A           0.0  25137783.0         US290029A            0
# 1     US129776A           0.0  19125884.0         US129776A            0
# 2     US265109A           0.0  19319070.0         US265109A            0
# 3     US169225A           0.0  39793614.0         US169225A            0
# 4     US359565A           0.0  16967309.0         US359565A            0
# ...         ...           ...         ...               ...          ...
# 2234  US307517A           0.0   4165317.0         US307517A            0
# ...

# %%
view1.to_csv('view1.csv', index = False)
